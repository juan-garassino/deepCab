# %% [markdown]
# # 08 — Prefect 3: @flow + @task + cron + serve
#
# **Scaffold** — section headings + one smoke cell. Full prose + exercises in a follow-up.

# %% [markdown]
# ## Setup smoke

# %%
from deepCab.flow_v2.retrain import retrain_flow, preprocess_task, train_task, evaluate_taskprint('Flow:', retrain_flow.name)print('Tasks:', preprocess_task.name, train_task.name, evaluate_task.name)

# %% [markdown]
# ## Sections to flesh out
#
# 1. Motivation — what problem this layer solves.
# 2. Walkthrough — read the key file, annotate.
# 3. Run — execute against a tiny synthetic example.
# 4. Exercise — modify X, observe Y.
# 5. References — links to the CLAUDE.md section + CONTRIBUTING runbook entries.
